# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
from citipy import citipy
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
#API call with the OpenWeatherMap.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2005bb288f295b0cbe33a1b50925264d

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | askino
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | stillwater
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 1 | bella union
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | bilma
# Processing Record 11 of Set 1 | tiznit
# Processing Record 12 of Set 1 | constantine
# Processing Record 13 of Set 1 | russell
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | tuy hoa
# Processing Record 18 of Set 1 | gunnedah
# Processing Record 19 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | luanda
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | zatoka
# Processing Record 24 of Set 1 | haines junction
# Processing Record 25 of Set 1 | porto novo
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | aksu
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | walvis bay
# Processing Record 33 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 1 | laurel
# Processing Record 35 of Set 1 | sangmelima
# Processing Record 36 of Set 1 | poya
# Processing Record 37 of Set 1 | lincoln
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | havre-saint-pierre
# Processing Record 43 of Set 1 | touros
# Processing Record 44 of Set 1 | eureka
# Processing Record 45 of Set 1 | inta
# Processing Record 46 of Set 1 | north bend
# Processing Record 47 of Set 1 | luganville
# Processing Record 48 of Set 1 | hovd
# Processing Record 49 of Set 1 | gerash
# Processing Record 50 of Set 1 | port macquarie
# Processing Record 1 of Set 2 | santa isabel do rio negro
# Processing Record 2 of Set 2 | kaeo
# Processing Record 3 of Set 2 | krasnoselkup
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | nkoteng
# Processing Record 6 of Set 2 | korla
# Processing Record 7 of Set 2 | raudeberg
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | kaseda
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | stornoway
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | dudinka
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | sinnamary
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | haverfordwest
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | elat
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | rincon
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | belle fourche
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | karratha
# Processing Record 35 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 2 | opobo
# City not found. Skipping...
# Processing Record 37 of Set 2 | dingle
# Processing Record 38 of Set 2 | coracao de jesus
# Processing Record 39 of Set 2 | moose factory
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | nhulunbuy
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | fairbanks
# Processing Record 47 of Set 2 | porgera
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | araria
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | yingcheng
# Processing Record 2 of Set 3 | grand gaube
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | pozo colorado
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | pacifica
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | boende
# Processing Record 17 of Set 3 | nishihara
# Processing Record 18 of Set 3 | danilovka
# Processing Record 19 of Set 3 | pinas
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | damietta
# Processing Record 23 of Set 3 | hamilton
# Processing Record 24 of Set 3 | songadh
# Processing Record 25 of Set 3 | ayan
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | tigil
# Processing Record 28 of Set 3 | talesh
# City not found. Skipping...
# Processing Record 29 of Set 3 | basco
# Processing Record 30 of Set 3 | smidovich
# Processing Record 31 of Set 3 | tamandare
# Processing Record 32 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | kutum
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | znamenskoye
# Processing Record 37 of Set 3 | shakiso
# Processing Record 38 of Set 3 | storslett
# Processing Record 39 of Set 3 | campbellton
# Processing Record 40 of Set 3 | vestmannaeyjar
# Processing Record 41 of Set 3 | hambantota
# Processing Record 42 of Set 3 | geraldton
# Processing Record 43 of Set 3 | loandjili
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | tual
# Processing Record 46 of Set 3 | atikokan
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | garissa
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | canon city
# Processing Record 2 of Set 4 | hithadhoo
# Processing Record 3 of Set 4 | monze
# Processing Record 4 of Set 4 | rio cuarto
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | marystown
# Processing Record 7 of Set 4 | waipawa
# Processing Record 8 of Set 4 | smithers
# Processing Record 9 of Set 4 | waddan
# Processing Record 10 of Set 4 | beringovskiy
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | vostok
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | plettenberg bay
# Processing Record 15 of Set 4 | conceicao do araguaia
# Processing Record 16 of Set 4 | jalu
# Processing Record 17 of Set 4 | cotija
# City not found. Skipping...
# Processing Record 18 of Set 4 | broome
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | bambous virieux
# Processing Record 24 of Set 4 | sawang daen din
# Processing Record 25 of Set 4 | neya
# Processing Record 26 of Set 4 | college
# Processing Record 27 of Set 4 | gremyachye
# City not found. Skipping...
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | jibuti
# Processing Record 33 of Set 4 | novyy urengoy
# Processing Record 34 of Set 4 | ulaanbaatar
# Processing Record 35 of Set 4 | chapais
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | egvekinot
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | longyearbyen
# Processing Record 40 of Set 4 | laguna
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | new norfolk
# Processing Record 43 of Set 4 | wilmington
# Processing Record 44 of Set 4 | bekhtery
# Processing Record 45 of Set 4 | zhoucheng
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | krasnyy yar
# Processing Record 48 of Set 4 | berbera
# Processing Record 49 of Set 4 | raduzhnyy
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | hobart
# Processing Record 2 of Set 5 | la ronge
# Processing Record 3 of Set 5 | beira
# Processing Record 4 of Set 5 | strathmore
# Processing Record 5 of Set 5 | asau
# Processing Record 6 of Set 5 | tooele
# Processing Record 7 of Set 5 | lixourion
# Processing Record 8 of Set 5 | kiama
# Processing Record 9 of Set 5 | ust-charyshskaya pristan
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 5 | kununurra
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | allende
# Processing Record 16 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 5 | abyek
# Processing Record 18 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 19 of Set 5 | sur
# Processing Record 20 of Set 5 | popondetta
# Processing Record 21 of Set 5 | caborca
# Processing Record 22 of Set 5 | kodiak
# Processing Record 23 of Set 5 | ribeira grande
# Processing Record 24 of Set 5 | ishigaki
# Processing Record 25 of Set 5 | hammerfest
# Processing Record 26 of Set 5 | dawei
# Processing Record 27 of Set 5 | waingapu
# Processing Record 28 of Set 5 | margate
# Processing Record 29 of Set 5 | nara
# Processing Record 30 of Set 5 | horsham
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | unity
# Processing Record 33 of Set 5 | nemuro
# Processing Record 34 of Set 5 | sakhon nakhon
# Processing Record 35 of Set 5 | auki
# Processing Record 36 of Set 5 | noyemberyan
# Processing Record 37 of Set 5 | salalah
# Processing Record 38 of Set 5 | san jose
# Processing Record 39 of Set 5 | fereydun kenar
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | saint-philippe
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | ballina
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | fukue
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | yining
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | kysyl-syr
# Processing Record 6 of Set 6 | chernyshevskiy
# Processing Record 7 of Set 6 | meulaboh
# Processing Record 8 of Set 6 | rapid city
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | nieves
# Processing Record 11 of Set 6 | sao felix do xingu
# Processing Record 12 of Set 6 | marsa matruh
# Processing Record 13 of Set 6 | yeppoon
# Processing Record 14 of Set 6 | calvinia
# Processing Record 15 of Set 6 | high level
# Processing Record 16 of Set 6 | coahuayana
# Processing Record 17 of Set 6 | port blair
# Processing Record 18 of Set 6 | manta
# Processing Record 19 of Set 6 | palana
# Processing Record 20 of Set 6 | coromandel
# Processing Record 21 of Set 6 | chokwe
# Processing Record 22 of Set 6 | bridlington
# Processing Record 23 of Set 6 | lorengau
# Processing Record 24 of Set 6 | sioux lookout
# Processing Record 25 of Set 6 | beloha
# Processing Record 26 of Set 6 | the pas
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | najran
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | narovchat
# Processing Record 32 of Set 6 | varna
# Processing Record 33 of Set 6 | tokur
# Processing Record 34 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 35 of Set 6 | chara
# Processing Record 36 of Set 6 | rongcheng
# Processing Record 37 of Set 6 | kholmogory
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | shache
# Processing Record 42 of Set 6 | zhangjiakou
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | nantucket
# Processing Record 45 of Set 6 | olsztyn
# Processing Record 46 of Set 6 | porto de moz
# Processing Record 47 of Set 6 | minot
# Processing Record 48 of Set 6 | riyadh
# Processing Record 49 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 6 | polunochnoye
# Processing Record 1 of Set 7 | orlik
# Processing Record 2 of Set 7 | wanning
# Processing Record 3 of Set 7 | umtata
# Processing Record 4 of Set 7 | paratinga
# Processing Record 5 of Set 7 | covington
# Processing Record 6 of Set 7 | boshnyakovo
# Processing Record 7 of Set 7 | villa de reyes
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | vao
# Processing Record 11 of Set 7 | emden
# Processing Record 12 of Set 7 | denpasar
# Processing Record 13 of Set 7 | lufilufi
# Processing Record 14 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 7 | manyana
# Processing Record 16 of Set 7 | taltal
# Processing Record 17 of Set 7 | cerkezkoy
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | yangjiang
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | bulawayo
# Processing Record 23 of Set 7 | pisco
# Processing Record 24 of Set 7 | cahors
# Processing Record 25 of Set 7 | pontianak
# Processing Record 26 of Set 7 | ayagoz
# Processing Record 27 of Set 7 | taoudenni
# Processing Record 28 of Set 7 | fortuna
# Processing Record 29 of Set 7 | tagusao
# Processing Record 30 of Set 7 | mogadishu
# Processing Record 31 of Set 7 | florence
# Processing Record 32 of Set 7 | chicomuselo
# Processing Record 33 of Set 7 | moron
# Processing Record 34 of Set 7 | husavik
# Processing Record 35 of Set 7 | manacapuru
# Processing Record 36 of Set 7 | tucurui
# Processing Record 37 of Set 7 | maniitsoq
# Processing Record 38 of Set 7 | praya
# Processing Record 39 of Set 7 | mehamn
# Processing Record 40 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 7 | dabhol
# Processing Record 42 of Set 7 | menongue
# Processing Record 43 of Set 7 | meadow lake
# Processing Record 44 of Set 7 | pochutla
# Processing Record 45 of Set 7 | port-cartier
# Processing Record 46 of Set 7 | wewak
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | segezha
# Processing Record 49 of Set 7 | simao
# Processing Record 50 of Set 7 | lucea
# Processing Record 1 of Set 8 | amapa
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | katherine
# Processing Record 4 of Set 8 | vardo
# Processing Record 5 of Set 8 | hervey bay
# Processing Record 6 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 8 | novikovo
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | ciuruleasa
# Processing Record 10 of Set 8 | nakambala
# Processing Record 11 of Set 8 | kirovskiy
# Processing Record 12 of Set 8 | port moresby
# Processing Record 13 of Set 8 | mahon
# Processing Record 14 of Set 8 | kyaikkami
# Processing Record 15 of Set 8 | fort walton beach
# Processing Record 16 of Set 8 | paamiut
# Processing Record 17 of Set 8 | kidal
# Processing Record 18 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 8 | alakurtti
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | siavonga
# Processing Record 22 of Set 8 | vikhorevka
# Processing Record 23 of Set 8 | abu samrah
# Processing Record 24 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 8 | san quintin
# Processing Record 26 of Set 8 | tazovskiy
# Processing Record 27 of Set 8 | monte alegre
# Processing Record 28 of Set 8 | acapulco
# Processing Record 29 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 8 | saint-augustin
# Processing Record 31 of Set 8 | iroquois falls
# Processing Record 32 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 8 | moerai
# Processing Record 34 of Set 8 | ambajogai
# Processing Record 35 of Set 8 | ende
# Processing Record 36 of Set 8 | alice springs
# Processing Record 37 of Set 8 | fallon
# Processing Record 38 of Set 8 | sisimiut
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | banda aceh
# Processing Record 41 of Set 8 | the hammocks
# Processing Record 42 of Set 8 | viareggio
# Processing Record 43 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 8 | danville
# Processing Record 45 of Set 8 | havelock
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | madang
# Processing Record 48 of Set 8 | tateyama
# Processing Record 49 of Set 8 | khorramabad
# Processing Record 50 of Set 8 | murgab
# Processing Record 1 of Set 9 | uthal
# Processing Record 2 of Set 9 | lakatoro
# Processing Record 3 of Set 9 | samarai
# Processing Record 4 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 9 | kotovsk
# Processing Record 9 of Set 9 | shaowu
# Processing Record 10 of Set 9 | chokurdakh
# Processing Record 11 of Set 9 | suntar
# Processing Record 12 of Set 9 | huangzhai
# Processing Record 13 of Set 9 | deli tua
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | canguaretama
# Processing Record 16 of Set 9 | rostovka
# Processing Record 17 of Set 9 | bahia honda
# Processing Record 18 of Set 9 | duncanville
# Processing Record 19 of Set 9 | faya
# Processing Record 20 of Set 9 | changping
# Processing Record 21 of Set 9 | acarau
# Processing Record 22 of Set 9 | bolshiye uki
# City not found. Skipping...
# Processing Record 23 of Set 9 | orillia
# Processing Record 24 of Set 9 | verkhnyaya toyma
# Processing Record 25 of Set 9 | mineiros
# Processing Record 26 of Set 9 | prado
# Processing Record 27 of Set 9 | marzuq
# Processing Record 28 of Set 9 | tarko-sale
# Processing Record 29 of Set 9 | eisenerz
# Processing Record 30 of Set 9 | kontagora
# Processing Record 31 of Set 9 | de-kastri
# Processing Record 32 of Set 9 | rodrigues alves
# Processing Record 33 of Set 9 | redmond
# Processing Record 34 of Set 9 | la suiza
# Processing Record 35 of Set 9 | maragogi
# Processing Record 36 of Set 9 | mitu
# Processing Record 37 of Set 9 | solnechnyy
# Processing Record 38 of Set 9 | saint anthony
# Processing Record 39 of Set 9 | kalmunai
# Processing Record 40 of Set 9 | doha
# Processing Record 41 of Set 9 | turka
# Processing Record 42 of Set 9 | kirchlinteln
# Processing Record 43 of Set 9 | san lorenzo
# Processing Record 44 of Set 9 | namibe
# Processing Record 45 of Set 9 | iquitos
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 9 | lazaro cardenas
# Processing Record 49 of Set 9 | mahina
# Processing Record 50 of Set 9 | kashira
# Processing Record 1 of Set 10 | nokaneng
# Processing Record 2 of Set 10 | luderitz
# Processing Record 3 of Set 10 | inhambane
# Processing Record 4 of Set 10 | rab
# City not found. Skipping...
# Processing Record 5 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 10 | shaartuz
# City not found. Skipping...
# Processing Record 7 of Set 10 | springfield
# Processing Record 8 of Set 10 | okhotsk
# Processing Record 9 of Set 10 | yingshang
# City not found. Skipping...
# Processing Record 10 of Set 10 | makakilo city
# Processing Record 11 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 10 | tessalit
# Processing Record 13 of Set 10 | matagami
# Processing Record 14 of Set 10 | vila praia de ancora
# Processing Record 15 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 16 of Set 10 | lagoa
# Processing Record 17 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 10 | rio gallegos
# Processing Record 19 of Set 10 | tokuyama
# Processing Record 20 of Set 10 | benghazi
# Processing Record 21 of Set 10 | luba
# Processing Record 22 of Set 10 | turukhansk
# Processing Record 23 of Set 10 | skegness
# Processing Record 24 of Set 10 | canutama
# Processing Record 25 of Set 10 | salinopolis
# Processing Record 26 of Set 10 | bengkulu
# Processing Record 27 of Set 10 | pangkalanbuun
# Processing Record 28 of Set 10 | souillac
# Processing Record 29 of Set 10 | jacareacanga
# Processing Record 30 of Set 10 | huron
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | bontang
# Processing Record 33 of Set 10 | seoul
# Processing Record 34 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 10 | albertville
# Processing Record 36 of Set 10 | suda
# Processing Record 37 of Set 10 | baruun-urt
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | patnanungan
# Processing Record 40 of Set 10 | pedasi
# Processing Record 41 of Set 10 | trairi
# Processing Record 42 of Set 10 | isangel
# Processing Record 43 of Set 10 | havoysund
# Processing Record 44 of Set 10 | pevek
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | coos bay
# Processing Record 47 of Set 10 | sambava
# Processing Record 48 of Set 10 | ternate
# Processing Record 49 of Set 10 | yar-sale
# Processing Record 50 of Set 10 | nanakuli
# Processing Record 1 of Set 11 | chavakkad
# Processing Record 2 of Set 11 | namalenga
# Processing Record 3 of Set 11 | manakara
# Processing Record 4 of Set 11 | conakry
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | nova olimpia
# Processing Record 7 of Set 11 | imisli
# City not found. Skipping...
# Processing Record 8 of Set 11 | opuwo
# Processing Record 9 of Set 11 | cayhagan
# Processing Record 10 of Set 11 | port lincoln
# Processing Record 11 of Set 11 | chicama
# Processing Record 12 of Set 11 | grand forks
# Processing Record 13 of Set 11 | amazar
# Processing Record 14 of Set 11 | west richland
# Processing Record 15 of Set 11 | anda
# Processing Record 16 of Set 11 | polyarnyy
# Processing Record 17 of Set 11 | saldanha
# Processing Record 18 of Set 11 | irbil
# Processing Record 19 of Set 11 | adelaide
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | barretos
# Processing Record 22 of Set 11 | udachnyy
# Processing Record 23 of Set 11 | kiunga
# Processing Record 24 of Set 11 | sungaipenuh
# Processing Record 25 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 26 of Set 11 | lichuan
# Processing Record 27 of Set 11 | nouakchott
# Processing Record 28 of Set 11 | buala
# Processing Record 29 of Set 11 | maraba
# Processing Record 30 of Set 11 | fredericton
# Processing Record 31 of Set 11 | bandarbeyla
# Processing Record 32 of Set 11 | san cristobal
# Processing Record 33 of Set 11 | tutoia
# Processing Record 34 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 11 | suarez
# Processing Record 36 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 11 | nayoro
# Processing Record 38 of Set 11 | rafai
# Processing Record 39 of Set 11 | sao geraldo do araguaia
# Processing Record 40 of Set 11 | pahrump
# Processing Record 41 of Set 11 | jha jha
# Processing Record 42 of Set 11 | soyo
# Processing Record 43 of Set 11 | abnub
# Processing Record 44 of Set 11 | ndele
# Processing Record 45 of Set 11 | mangan
# Processing Record 46 of Set 11 | lucapa
# Processing Record 47 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 11 | nizhnyaya tavda
# Processing Record 49 of Set 11 | soto la marina
# Processing Record 50 of Set 11 | kavaratti
# Processing Record 1 of Set 12 | awjilah
# Processing Record 2 of Set 12 | jadu
# Processing Record 3 of Set 12 | rosario do sul
# Processing Record 4 of Set 12 | shingu
# Processing Record 5 of Set 12 | gat
# Processing Record 6 of Set 12 | ereymentau
# Processing Record 7 of Set 12 | belen
# Processing Record 8 of Set 12 | bonthe
# Processing Record 9 of Set 12 | san ramon
# Processing Record 10 of Set 12 | okakarara
# Processing Record 11 of Set 12 | bull savanna
# Processing Record 12 of Set 12 | de aar
# Processing Record 13 of Set 12 | pinega
# Processing Record 14 of Set 12 | hualmay
# Processing Record 15 of Set 12 | ekhabi
# Processing Record 16 of Set 12 | katsuura
# Processing Record 17 of Set 12 | gizo
# Processing Record 18 of Set 12 | xuanzhou
# Processing Record 19 of Set 12 | nueva loja
# Processing Record 20 of Set 12 | ossett
# Processing Record 21 of Set 12 | quimper
# Processing Record 22 of Set 12 | araouane
# Processing Record 23 of Set 12 | sobolevo
# Processing Record 24 of Set 12 | thinadhoo
# Processing Record 25 of Set 12 | juneau
# Processing Record 26 of Set 12 | turayf
# Processing Record 27 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 12 | concordia
# Processing Record 29 of Set 12 | challapata
# Processing Record 30 of Set 12 | zhuhai
# Processing Record 31 of Set 12 | iquique
# Processing Record 32 of Set 12 | ferrol
# Processing Record 33 of Set 12 | marsaxlokk
# Processing Record 34 of Set 12 | humberto de campos
# Processing Record 35 of Set 12 | vila velha
# Processing Record 36 of Set 12 | bollnas
# Processing Record 37 of Set 12 | manono
# Processing Record 38 of Set 12 | mnogovershinnyy
# Processing Record 39 of Set 12 | sao jose da coroa grande
# Processing Record 40 of Set 12 | ha tinh
# Processing Record 41 of Set 12 | talnakh
# Processing Record 42 of Set 12 | sam roi yot
# Processing Record 43 of Set 12 | bilibino
# Processing Record 44 of Set 12 | anloga
# Processing Record 45 of Set 12 | aswan
# Processing Record 46 of Set 12 | nichinan
# Processing Record 47 of Set 12 | itarema
# Processing Record 48 of Set 12 | darab
# Processing Record 49 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 50 of Set 12 | saint-louis
# Processing Record 1 of Set 13 | divnomorskoye
# Processing Record 2 of Set 13 | dwarka
# Processing Record 3 of Set 13 | macia
# Processing Record 4 of Set 13 | yingkou
# Processing Record 5 of Set 13 | moindou
# Processing Record 6 of Set 13 | noumea
# Processing Record 7 of Set 13 | swan river
# Processing Record 8 of Set 13 | cisarua
# Processing Record 9 of Set 13 | shaunavon
# Processing Record 10 of Set 13 | svetlaya
# Processing Record 11 of Set 13 | urucui
# Processing Record 12 of Set 13 | ahipara
# Processing Record 13 of Set 13 | iwanai
# Processing Record 14 of Set 13 | nizwa
# Processing Record 15 of Set 13 | goderich
# Processing Record 16 of Set 13 | turiacu
# Processing Record 17 of Set 13 | abengourou
# Processing Record 18 of Set 13 | sept-iles
# Processing Record 19 of Set 13 | aneho
# Processing Record 20 of Set 13 | chancay
# Processing Record 21 of Set 13 | lulea
# Processing Record 22 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 23 of Set 13 | marseille
# Processing Record 24 of Set 13 | adrar
# Processing Record 25 of Set 13 | nanortalik
# Processing Record 26 of Set 13 | zhangye
# Processing Record 27 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 13 | davila
# Processing Record 31 of Set 13 | magadan
# Processing Record 32 of Set 13 | jeremie
# Processing Record 33 of Set 13 | vanavara
# Processing Record 34 of Set 13 | sri aman
# Processing Record 35 of Set 13 | taunggyi
# Processing Record 36 of Set 13 | guanambi
# Processing Record 37 of Set 13 | warmbad
# Processing Record 38 of Set 13 | comodoro rivadavia
# Processing Record 39 of Set 13 | emerald
# Processing Record 40 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 41 of Set 13 | la paz
# Processing Record 42 of Set 13 | grand-lahou
# Processing Record 43 of Set 13 | cascais
# Processing Record 44 of Set 13 | estelle
# Processing Record 45 of Set 13 | saint-gedeon
# Processing Record 46 of Set 13 | yichun
# Processing Record 47 of Set 13 | yauya
# Processing Record 48 of Set 13 | pamekasan
# Processing Record 49 of Set 13 | bestobe
# Processing Record 50 of Set 13 | fort nelson
# Processing Record 1 of Set 14 | mezen
# Processing Record 2 of Set 14 | svetlyy
# Processing Record 3 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 14 | tacuarembo
# Processing Record 5 of Set 14 | kisangani
# Processing Record 6 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 14 | vrangel
# Processing Record 8 of Set 14 | hohhot
# Processing Record 9 of Set 14 | mizdah
# Processing Record 10 of Set 14 | vallenar
# Processing Record 11 of Set 14 | osypenko
# Processing Record 12 of Set 14 | ellisras
# Processing Record 13 of Set 14 | mayo
# Processing Record 14 of Set 14 | te anau
# Processing Record 15 of Set 14 | teahupoo
# Processing Record 16 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 17 of Set 14 | gniezno
# Processing Record 18 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 14 | klyuchi
# Processing Record 20 of Set 14 | mutsu
# Processing Record 21 of Set 14 | madison
# Processing Record 22 of Set 14 | hokitika
# Processing Record 23 of Set 14 | marsh harbour
# Processing Record 24 of Set 14 | scarborough
# Processing Record 25 of Set 14 | elko
# Processing Record 26 of Set 14 | zemio
# Processing Record 27 of Set 14 | tchibanga
# Processing Record 28 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 14 | rawicz
# Processing Record 30 of Set 14 | oranjemund
# Processing Record 31 of Set 14 | yuzhne
# Processing Record 32 of Set 14 | saint stephen
# Processing Record 33 of Set 14 | sungai besar
# Processing Record 34 of Set 14 | ustka
# Processing Record 35 of Set 14 | vila
# Processing Record 36 of Set 14 | xuddur
# Processing Record 37 of Set 14 | qaqortoq
# Processing Record 38 of Set 14 | tsingoni
# Processing Record 39 of Set 14 | calama
# Processing Record 40 of Set 14 | kathmandu
# Processing Record 41 of Set 14 | villa union
# Processing Record 42 of Set 14 | bratsk
# Processing Record 43 of Set 14 | mayumba
# Processing Record 44 of Set 14 | minna
# Processing Record 45 of Set 14 | barra do garcas
# Processing Record 46 of Set 14 | zhenlai
# Processing Record 47 of Set 14 | vinces
# Processing Record 48 of Set 14 | hofn
# Processing Record 49 of Set 14 | bari
# Processing Record 50 of Set 14 | zapolyarnyy
# Processing Record 1 of Set 15 | hirado
# Processing Record 2 of Set 15 | andros town
# Processing Record 3 of Set 15 | mugur-aksy
# Processing Record 4 of Set 15 | vestmanna
# Processing Record 5 of Set 15 | simplicio mendes
# Processing Record 6 of Set 15 | cottage grove
# Processing Record 7 of Set 15 | severnyy-kospashskiy
# Processing Record 8 of Set 15 | severo-yeniseyskiy
# Processing Record 9 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 15 | yekimovichi
# Processing Record 11 of Set 15 | siniscola
# Processing Record 12 of Set 15 | manzhouli
# Processing Record 13 of Set 15 | palmer
# Processing Record 14 of Set 15 | cooma
# Processing Record 15 of Set 15 | taldan
# Processing Record 16 of Set 15 | longyan
# Processing Record 17 of Set 15 | encruzilhada
# Processing Record 18 of Set 15 | sistranda
# Processing Record 19 of Set 15 | sola
# Processing Record 20 of Set 15 | rieti
# Processing Record 21 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 15 | lock haven
# Processing Record 23 of Set 15 | golden
# Processing Record 24 of Set 15 | nizhniy kuranakh
# Processing Record 25 of Set 15 | marang
# Processing Record 26 of Set 15 | peniche
# Processing Record 27 of Set 15 | ulaangom
# Processing Record 28 of Set 15 | pacific grove
# Processing Record 29 of Set 15 | tongren
# Processing Record 30 of Set 15 | moyale
# Processing Record 31 of Set 15 | hailar
# Processing Record 32 of Set 15 | sorong
# Processing Record 33 of Set 15 | bara
# Processing Record 34 of Set 15 | odweyne
# Processing Record 35 of Set 15 | kailua
# Processing Record 36 of Set 15 | altay
# Processing Record 37 of Set 15 | lodja
# Processing Record 38 of Set 15 | san carlos
# Processing Record 39 of Set 15 | kloulklubed
# Processing Record 40 of Set 15 | pietarsaari
# Processing Record 41 of Set 15 | sabzevar
# Processing Record 42 of Set 15 | zyryanka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Askino      RU  56.0901   56.5783     69.06        41           0
# 1         Chuy      UY -33.6971  -53.4616     59.29        93           5
# 2   Stillwater      US  36.1156  -97.0584     82.89        75          40
# 3         Lebu      CL -37.6167  -73.6500     46.06        71          92
# 4       Hasaki      JP  35.7333  140.8333     79.20        95         100
# 5  Bella Union      UY -30.2752  -57.6007     62.37        71           0
# 6        Tiksi      RU  71.6872  128.8694     51.15        69          29
# 7     Tasiilaq      GL  65.6145  -37.6368     44.76        97         100
# 8        Bilma      NE  18.6853   12.9164     88.77        45          83
# 9       Tiznit      MA  29.5833   -9.5000     63.10        91          34
#
#    Wind Speed Current Description
# 0       11.90           clear sky
# 1        5.17           clear sky
# 2        1.99    scattered clouds
# 3       16.33     overcast clouds
# 4       30.98       moderate rain
# 5        8.81           clear sky
# 6        5.21    scattered clouds
# 7       15.61       moderate rain
# 8       16.55       broken clouds
# 9        2.21    scattered clouds

# %%
# Create CSV file of DF
csv_weather_file = "Weather_Database/WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
